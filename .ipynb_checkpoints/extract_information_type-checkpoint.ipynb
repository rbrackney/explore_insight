# %% [markdown]
# <h3> Extract Insight Profile features </h3>
# Insight profiles were copied directly from a .js script on the insight data science page. It contains the name of each fellow, their university, their demo project name, the company that hired them, and their job title.
# This notebook uses regular expressions to extract those features into a useable format.

# %%
import re
import pandas as pd
import seaborn as svs

# %matplotlib inline

# %%
def get_features(ind):
    '''
    ind: the string block containing containing the information for a single individual, 
    taken from the 'insight_profiles' file. See next cell for info on that.
    
    '''
    j_t = re.findall('font-weight:600;">(.*?)</div>', ind, re.DOTALL)
    if len(j_t) == 3:
        j_t = j_t[1].split(',')
    elif len(j_t) == 2:
        j_t = j_t[0].split(',')
    else:
        j_t = j_t[0].split(',')
    
    if len(j_t) == 2:
        job_title = j_t[0].strip()
        company = j_t[1]
    else:
        job_title = j_t[0].strip()
        company =  '?'
        
    ''' clean up company'''
    
    _c = re.sub('<br>', '', company)
    _c = re.sub('</br>', '', _c)
    _c = re.sub('[&#39;]', '', _c)
    company = _c.strip()
    
    project_title = re.findall('20px;">(.*?)</div>', ind, re.DOTALL)[0].strip()
    
    _back = re.search('Background(.*)', ind).group(1)
    university = _back.split('<br>')[1].strip()
    #university =re.findall('<br>(.*?)<br>', ind, re.DOTALL)[0].strip()
    background =re.findall('6px;">(.*?)<br>', ind, re.DOTALL)[0].strip()
    out_dict = {'job_title': job_title,
                'company':company, 
                'project_title':project_title,
               'university':university,
               'background':background}
    
    return out_dict

# %% [markdown]
# <h4>Extract all basic info from the flat file

# %%
with open('insight_profiles') as f:
    ftxt = f.read()

# %%
'''fellows_info is a list where each item is dictionary of features for that fellow'''
individuals =  re.findall ( '[*][*]/(.*?)/[*][*]', ftxt, re.DOTALL)
fellows_info = list()
for ind in individuals:
    fellows_info.append(get_features(ind))

# %% [markdown]
# <h4>Create a count of the number of fellows that were hired by each company

# %%
'''count the number of fellows that went to each company'''
company_set = set()
company_dict = {}
for fellow in fellows_info:
    com = fellow['company'] 
    if com in company_set:
        
        company_dict[com] += 1
    else:
        company_set.add(com)
        company_dict[com] = 1

# %%
company_series = pd.Series(company_dict).to_frame()
company_series.to_excel('companies.xlsx', sheet_name='s')

# %%
plot_series = company_series.sort(columns = [0], ascending = False)
plot_series.loc['Insight Data Science'] = 10
plot_series = plot_series.drop(['Insight','?'])
plot_series = plot_series.sort(columns = [0], ascending = False)

# %%
cur_plot = plot_series.plot(kind = 'bar')
cur_plot.set_xlim([-0.5, 9.5])
cur_plot.legend_.remove()
cur_plot.set_title('companies that love insight the most')
cur_plot.set_ylabel('# of lucky fellows with jobs at company')
fig = cur_plot.get_figure()
fig.patch.set_facecolor('white') #set the facecolor so it's not transparent

# %% [markdown]
# <h4> Plot the University that each fellow came from before Insight

# %%
'''assuming that the fellows_info list already exists'''
univ_set = set()
univ_dict = {}

replace_dict=  {'Stanford':'Stanford University',
                'Yale':'Yale University',
                'Lawrence Berkeley': 'Lawrence Berkeley National Laboratory',
                'University of Waterloo':'University of Waterloo',
                'University of Texas':'University of Texas, Austin',
                'Caltech': 'California Institute of Technology',
                'UC Berkeley':'University of California, Berkeley',
                'U.C. Berkeley':'University of California, Berkeley',
                'Boston University':'Boston University',
                'MIT': 'Massachusetts Institute of Technology',
                'University of British Columbia':'University of British Columbia',
                'UC San Diego': 'University of California, San Diego',
                'UC Santa Cruz': 'University of California, Santa Cruz',
                'UC Davis': 'University of California, Davis'
               } 

for fellow in fellows_info:
    u = fellow['university'] 
    _u = re.sub('[&#47]', '', u)
    u = _u
    
    for k in replace_dict.keys():
        if k.lower() in u.lower():
            u = replace_dict[k]
    if u in univ_set:        
        univ_dict[u]['count'] += 1
    else:
        univ_set.add(u)
        univ_dict[u] = {'count':1}

# %%
cur_plot = pd.DataFrame(univ_dict).transpose().sort(columns = ['count'], ascending = False).plot(kind='bar')
cur_plot.set_xlim([-0.5, 13.5])
cur_plot.legend_.remove()
cur_plot.set_title('universities that Insight loves the most')
cur_plot.set_ylabel('# of academic defectors')
fig = cur_plot.get_figure()
fig.patch.set_facecolor('white')

# %% [markdown]
# <h4> Now map the universities

# %%
with open('google.apik', 'r') as f:
    apikey = f.read()

# %%
def mapinfo(in_location, apikey):
    instr = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=%s&key=%s' % (in_location,apikey)
    loc_info = requests.get(instr).json()
    return loc_info

# %%
call_api = True
if call_api:
    for k in univ_dict.keys():
        print 'trying %s' % k
        try:
            univ_dict[k]['map_info'] = mapinfo(k,apikey)
        except:
            print '%s exception' % k
else:
    print 'call_api is off'
# Out:
# trying Brown University
# trying Rice University
# trying University of Florida
# trying University of Tokyo
# trying Dalhousie University
# trying Swinburne University
# trying Mount Sinai School of Medicine
# trying Australian National University
# trying University of California, Los Angeles
# trying University of California, Irvine
# trying Paris Observatory
# trying North Carolina State University
# trying University of Illinois at Urbana-Champaign
# trying Brookhaven National Laboratory
# trying NYC School of Medicine
# trying University of Pittsburgh
# trying University of Michigan
# trying University of Pennsylvania
# trying City University of New York
# trying University of British Columbia
# trying Swiss Federal Institute of Technology Zurich
# trying Institute for Space Science, Barcelona, Spain
# trying Boston University
# trying The Pennsylvania State University
# trying University of California,
# trying Signal Processing
# trying University of Waterloo
# trying New York University
# trying Harvard University
# trying University of California, San Diego
# trying Drexel University
# trying WiTricity Corporation
# trying Boston College
# trying Georgetown University
# trying University of Maryland
# trying Brandeis University
# trying ECARES, ULB
# trying University of Colorado, Boulder
# trying University of Minnesota
# trying University of New Hampshire
# trying Icahn School of Medicine at Mount Sinai
# trying One Acre Fund
# trying Texas Christian University
# trying Johns Hopkins University
# trying Rutgers University
# trying Penn State
# trying University of Oxford
# trying California Polytechnic State University
# trying University of California, Santa Barbara
# trying Virginia Tech
# trying J. Craig Venter Institute
# trying University of Texas, Austin
# trying Stanford University
# trying Harvard Medical School
# trying Kavli Institute for Theoretical Physics, UC Santa Barbara
# trying University of California, Merced
# trying University of California, Berkeley
# trying California Institute of Technology
# trying University of Technology Sydney, Australia
# trying University of California, San Francisco
# trying Uniersity of California,
# trying The Ohio State University
# trying Georgia Institute of Technology/Emory University
# trying Weill Cornell Medical College
# trying University of Exeter
# trying Columbia University
# trying Lawrence Berkeley National Laboratory
# trying University of California, Santa Cruz
# trying Pardee RAND Graduate School
# trying University of Virginia
# trying Oracle
# trying Case Western Reserve University
# trying Princeton University
# trying University of Iowa
# trying University of Wisconsin - Madison
# trying Institute for Advanced Study, Princeton
# trying Yale University
# trying University of Utah
# trying Northeastern University
# trying University of Sussex
# trying University of Arizona
# trying Stony Brook University
# trying University of Washington
# trying Purdue University
# trying Massachusetts Institute of Technology
# trying University of Notre Dame
# trying ETH Zurich
# trying University Carlos III of Madrid
# trying Carnegie Mellon University
# trying Northwestern University
# trying Wisconsin IceCube Particle Astrophysics Center
# trying Niels Bohr Institute, Copenhagen University
# trying University of California, Davis
# trying University of California, Riverside
# trying University of Chicago
# trying Cornell University
# trying University of Colorado Boulder
# trying University of Hawaii
# trying Duke University
# trying Tufts University
# trying University of Victoria
# trying University of Toronto
# trying Max Planck Institute for Astrophysics
# trying University of Cambridge

# %%
'''to save API calls, only do this once if possible'''
import pickle
pickle.dump( univ_dict, open( "university.pkl", "wb" ) )

# %%
for k,v in univ_dict.iteritems():
    map_loc = v['map_info'][u'results'][0]['geometry']['location']
    univ_dict[k]['loc'] = map_loc

# %%
map_loc
# Out:
# {u'lat': 52.20426659999999, u'lng': 0.1149085}

# %%
import folium
from IPython.display import HTML
#map_osm = folium.Map(location=[45.5236, -122.6750])
map_osm = folium.Map()


def inline_map(m, width=650, height=500):
    """Takes a folium instance and embed HTML."""
    m._build_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{}" '
                 'style="width: {}px; height: {}px; '
                 'border: none"></iframe>'.format(srcdoc, width, height))
    return embed
exclusions = ['Signal Processing','One Acre Fund','Oracle'] #don't add these "universities"
for k,v in univ_dict.iteritems():
    if k not in exclusions:
        location = [v['loc']['lat'],v['loc']['lng']]

        place_count = '%s, # of Fellows: %d' % (k, v['count'])
        map_osm.simple_marker(location=location, popup=place_count)
    
map_osm.create_map(path='insight_universities.html')
inline_map(map_osm)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#   <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/andrewgiessel/leafletstuff/master/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_aa3c460cf22b42e89270042879f857c3&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_aa3c460cf22b42e89270042879f857c3', {
#                                        center:[0, 0],
#                                        zoom: 1,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       /*
#       addition of the image layers
#       */
#
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([41.8267718,
# 							-71.4025482],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Brown University, # of Fellows: 2&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([29.7173941,
# 							-95.4018312],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Rice University, # of Fellows: 2&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([29.6436325,
# 							-82.3549302],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;University of Florida, # of Fellows: 1&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([35.7126775,
# 							139.761989],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;University of Tokyo, # of Fellows: 1&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([44.6365812,
# 							-63.5916555],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;Dalhousie University, # of Fellows: 1&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([-37.822149,
# 							145.038961],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;Swinburne University, # of Fellows: 1&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([40.789057,
# 							-73.9530983],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;Mount Sinai School of Medicine, # of Fellows: 1&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([-35.2776999,
# 							149.118527],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;Australian National University, # of Fellows: 1&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([34.068921,
# 							-118.4451811],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;University of California, Los Angeles, # of Fellows: 3&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([33.6404952,
# 							-117.8442962],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;University of California, Irvine, # of Fellows: 2&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerCo
