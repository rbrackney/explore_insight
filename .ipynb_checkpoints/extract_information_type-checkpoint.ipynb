# %%
import re
import pandas as pd

# %%
with open('insight_profiles') as f:
    ftxt = f.read()

# %%
def get_features(ind):
    '''
    ind: the string block containing containing the information for a single individual
    
    '''
    j_t = re.findall('font-weight:600;">(.*?)</div>', ind, re.DOTALL)
    if len(j_t) == 3:
        j_t = j_t[1].split(',')
    elif len(j_t) == 2:
        j_t = j_t[0].split(',')
    else:
        j_t = j_t[0].split(',')
    
    if len(j_t) == 2:
        job_title = j_t[0].strip()
        company = j_t[1]
    else:
        job_title = j_t[0].strip()
        company =  '?'
        
    project_title = re.findall('20px;">(.*?)</div>', ind, re.DOTALL)[0].strip()
    university =re.findall('<br>(.*?)<br>', ind, re.DOTALL)[0].strip()
    background =re.findall('6px;">(.*?)<br>', ind, re.DOTALL)[0].strip()
    out_dict = {'job_title': job_title,
                'company':company, 
                'project_title':project_title,
               'university':university,
               'background':background}
    
    return out_dict

# %%
individuals =  re.findall ( '[*][*]/(.*?)/[*][*]', ftxt, re.DOTALL)
company_set = set()
company_dict = {}
for ind in individuals:
    out_dict = get_features(ind)
    #out_dict['company'] = out_dict['company'].strip(' ').strip('  ').strip('<br>').strip('</br>').rstrip(' ')
    #out_dict['company'] = out_dict['']
    com = out_dict['company']
    if com in company_set:
        
        company_dict[com] += 1
    else:
        company_set.add(com)
        company_dict[com] = 1

# %%
company_set
new_company_set = set()
for i in company_set:

    new_company_set.add(b)
print new_company_set
# Out:
# set(['KQR', 'LendUp', 'SalesforceIQ', '6 Sense Insights Inc.', 'Khan Academy', 'Sparked.com', 'Outrigger Media', 'Airbnb', 'Walmart Labs', 'Counsyl', 'In-Q-Tel', 'LearnVest', 'TaskRabbit', 'Trunk Club', 'Prosper', 'Grand Rounds Inc.', 'Google (Youtube)', 'Athos', 'Chango', 'Yelp', 'iMatchative Inc.', 'Rasa Networks', 'Grand Rounds', 'Go Auto', 'Apple', 'Level Up Analytics', 'Telefonica', 'Capital One', 'Rentlytics', 'URX', 'Wallet.io', 'Dstillery', 'Adobe', 'Insight Data Science', 'LendLayer', 'MTV Networks', 'Modcloth', 'Oscar Insurance', 'Payoff', 'RadiumOne', 'Illumina', 'Memorial Sloan Kettering Cancer Center', 'Udacity', 'Akamai', 'Premise Data Corporation', 'AvantCredit', 'Gilt Group', 'Capital One Labs', 'KPMG', 'Stitch Fix', 'Birchbox', 'Optimizely', 'Adroll', 'Beats Music', 'Vested Finance', 'Amazon', 'Facebook', 'Enigma', 'Premise', 'InVitae', 'Glassdoor.com', 'Microsoft (Yammer)', 'Kabam', '?', 'Pebble Tech', 'NBC Universal', 'Blue Apron', 'Homejoy', 'Custora', 'Tapad', 'Supply at Adroll', 'Square', 'Sling Media', 'Keep.com', 'Insight', 'Groupon', 'Palantir', 'Element Analytics', 'Interana Inc.', 'Picwell', 'Fino Consulting', 'Pebble', 'Voxer', 'Philips Research', 'YP Mobile Labs', 'Stealth Mode Security Startup', 'Axon Vibe', 'SecurityScorecard', 'Product Quality Operations at Google', 'ATT', 'CreativeLive', 'Bosch', 'Hampton Creek', 'Enlitic', 'RichRelevance', 'Zacsi', 'Nauto', 'Biogen Idec', 'StubHub', 'Vectra Networks', 'OnDeck', 'Edmodo', 'Sojern', 'Dow Jones', 'ZocDoc', 'Via', 'Glassdoor', 'Bosch North America', 'LA Dodgers', 'Twitter', 'Quottly', 'Civis Analytics', 'Silicon Valley Data Science', 'CreativeLIVE', 'RedOwl Analytics', 'Macys', 'The New York Times', 'BitSight Technologies', 'LinkedIn', 'Samba TV', 'RelateIQ', 'JPMorgan Chase  Co.', 'Tamr', 'creativeLIVE', 'StoryCloud', 'BloomReach', '2andMe', '6Sense', 'Sparked', 'Bloomberg', 'BlackRock', 'Sentry Data Systems', 'Yammer', 'Kixeye', 'TripAdvisor', 'McKesson', 'Netflix', 'MTV', 'The Goodyear Tire  Rubber Company', 'PlotWatt', 'Intuit', 'Elasticsearch', 'Teralytics', 'Schireson', 'Palantir Technologies', 'Uber', 'Pacific Biosciences', 'Discover Technologies (Consumer Financial Protection Bureau)', 'Insight Health Data Science', 'Sailthru', 'Cisco', 'Lumiata', 'AthenaHealth', 'Brilliant.org', 'Zillabyte', 'InfoChimps'])

# %%
company_series = pd.Series(company_dict).to_frame()
company_series.to_excel('companies.xlsx', sheet_name='s')

# %%
company_series
# Out:
#                                      0
#  Capital One                         1
#  Stitch Fix                          1
# 23andMe                              1
# 6 Sense Insights Inc.                1
# 6Sense                               1
# ?                                   14
# AT&T                                 2
# Adobe                                1
# Adroll                               1
# Airbn                                5
# Akamai                               1
# Amazon                               1
# Apple                                3
# AthenaHealth                         1
# Athos                                1
# AvantCredit                          1
# Axon Vibe                            4
# Beats Music                          1
# Biogen Idec                          2
# Birchbox                             1
# BitSight Technologies                1
# BlackRock                            1
# BloomReach                           1
# Bloomberg                            4
# Blue Apron                           1
# Bosch                                1
# Bosch North America                  1
# Brilliant.org                        1
# Capital One                          2
# Capital One Labs                     1
# ...                                 ..
# StoryCloud                           1
# StubHu                               1
# Supply at Adroll                     1
# Tam                                  1
# Tapad                                2
# TaskRabbit                           1
# Telefonica                           1
# Teralytics                           1
# The Goodyear Tire & Rubber Company   1
# The New York Times                   1
# TripAdviso                           1
# Trunk Clu                            1
# Twitte                               4
# URX                                  1
# Ube                                  1
# Udacity                              1
# Vectra Networks                      1
# Vested Finance                       2
# Via                                  1
# Voxe                                 1
# Wallet.io                            1
# Walmart Labs                         1
# YP Mobile Labs                       1
# Yamme                                5
# Yelp                                 5
# Zacsi                                1
# Zillabyte                            1
# ZocDoc                               1
# creativeLIVE                         1
# iMatchative Inc.                     1
#
# [158 rows x 1 columns]

# %%
j_t = re.findall('font-weight:600;">(.*?)</div>', ind, re.DOTALL)
print j_t
# Out:
# [' Megan Cartwright ', ' Quantitative Analyst ', 'Background']

# %%
ind
# Out:
# '\n\n$(document).ready(function() {\n\t$("[rel=Megan]").popover({\n\t    placement : \'top\', //placement of the popover. also can use top, bottom, left or right\n\t    title : \'<div style="text-align:center; font-size:16px; color:#424442; font-weight:600;"> Megan Cartwright </div><div style="text-align:center; font-size:15px; color:#424442; font-weight:600;"> Quantitative Analyst </div>\', //this is the top title bar of the popover. add some basic css\n\t\ttrigger: \'hover\', \n\t\thtml: \'true\', //needed to show html of course\n\t\tcontent : \'<div style="padding-bottom:10px; padding-top:6px; color:#424442; font-weight:600; ">Insight Project</div> <div style="font-weight:120;  font-size:14px; color:#424442; padding-bottom:20px;"> Stay Connected: The People You Remember Not to Forget </div> <div style=" padding-bottom:10px; color:#424442; font-weight:600;">Background</div> <div style="color:#424442; font-weight:120; font-size:14px; padding-bottom:6px;"> Space Plasma Physics <br> University of California, Berkeley <br> Postdoctoral Researcher </div>\'\n\t\t\t //this is the content of the html box. add the image here or anything you want really.\n\t});\t\n\t});\n\n'
